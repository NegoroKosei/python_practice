# %%
import pandas as pd
# pd.read_csv # csvファイルの読み込み
# pd.tail(n) # 後ろからn行抽出
# pd.head(n) # 前から
data = {
        'name':['根来','加藤','田中'],
        'stature':[170, 160, 165],
        'kcal':[30.5, 14.5, 0]
}
df = pd.DataFrame(data)
df[['name','kcal']].head() # nameとkcalのcolumunsを抽出
# Out:
#   name  kcal
# 0   根来  30.5
# 1   加藤  14.5
# 2   田中   0.0

# %%
df.loc[1000] # 1000行目を抽出
df.iloc[1:3, [2,4]] #1-2行目、2,4列目を抽出

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/processed_datamart.csv',sep = ',')

# データの確認
print('dataframeの行数・列数の確認==>\n', df.shape)
print('indexの確認==>\n', df.index)
print('columnの確認==>\n', df.columns)
print('dataframeの各列のデータ型を確認==>\n', df.dtypes)
# Out:
# dataframeの行数・列数の確認==>
#  (164, 158)
# indexの確認==>
#  RangeIndex(start=0, stop=164, step=1)
# columnの確認==>
#  Index(['datetime', 'sales', 'soldout', 'kcal', 'payday', 'precipitation',
#        'temperature', 'month', 'day', 'temperature_diff',
#        ...
#        'weather_快晴', 'weather_晴れ', 'weather_曇', 'weather_薄曇', 'weather_雨',
#        'weather_雪', 'weather_雷電', 'period_上旬', 'period_中旬', 'period_下旬'],
#       dtype='object', length=158)
# dataframeの各列のデータ型を確認==>
#  datetime       object
# sales           int64
# soldout         int64
# kcal          float64
# payday        float64
#                ...
# weather_雪       int64
# weather_雷電      int64
# period_上旬       int64
# period_中旬       int64
# period_下旬       int64
# Length: 158, dtype: object

# %%
df.head()
# Out:
#      datetime  sales  soldout   kcal  payday  precipitation  temperature  \
# 0  2014-01-09    129        1  435.0     0.0            0.0         10.9
# 1  2014-01-10     87        0  440.0     1.0            0.0          5.1
# 2  2014-01-14    129        1  376.0     0.0            0.0          5.8
# 3  2014-01-15    134        0  450.0     0.0            0.0          2.9
# 4  2014-01-16    107        0  415.0     0.0            0.0          7.0
#
#    month  day  temperature_diff  ...  weather_快晴  weather_晴れ  weather_曇  \
# 0      1    9               1.1  ...           0           0          1
# 1      1   10              -5.8  ...           1           0          0
# 2      1   14               0.7  ...           0           1          0
# 3      1   15              -2.9  ...           0           0          1
# 4      1   16               4.1  ...           1           0          0
#
#    weather_薄曇  weather_雨  weather_雪  weather_雷電  period_上旬  period_中旬  \
# ...

# %%
df.rename(columns={'y':'sales'}, inplace = True) #columns'y'を'sales'に変換
df.sort_values(by = 'sales',ascending = True) #columns名の列でソート ascending=Trueで昇順
# by =カラム名　を　カラム名の配列　とすることで複数のソートが可能)
#df,isnull().sum #
# Out:
#        datetime    y  soldout   kcal  payday  precipitation  temperature  \
# 159  2014-09-22   29        0  395.0     0.0            0.0         25.2
# 130  2014-08-01   38        0  380.0     0.0            0.0         32.7
# 145  2014-08-29   39        0  398.0     0.0            0.0         25.1
# 136  2014-08-12   40        1  400.0     0.0            0.0         29.4
# 163  2014-09-30   40        0  398.0     0.0            0.0         28.1
# ..          ...  ...      ...    ...     ...            ...          ...
# 35   2014-03-03  131        0  407.0     0.0            0.0          7.8
# 3    2014-01-15  134        0  450.0     0.0            0.0          2.9
# 25   2014-02-17  137        1  416.0     0.0            0.0         11.6
# 21   2014-02-10  137        0  423.0     1.0            0.0          7.8
# 16   2014-02-03  139        1  445.0     0.0            0.0         15.9
#
#      month  day  temperature_diff  ...  weather_快晴  weather_晴れ  weather_曇  \
# ...

# %%
df.

# %%
df.to_csv('保存アドレス',encoding = 'utf-8')
